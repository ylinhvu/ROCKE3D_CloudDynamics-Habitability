# %%
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib as mpl
import master_ROCKE3D as mr
import os, glob

from matplotlib import gridspec, colorbar, colors
from netCDF4 import Dataset
from numpy import ma

# %%
def sorter(filename):
    """
    Get an item from the list (one-by-one) and return a score for that item.
    Sorts based on PXXX in the .nc filename which occurs at the 17th-21st index for the files I'm looking at
    """
    return filename[17:21]

# %%
insolation = [1.0, 1.1, 1.2, 1.3, 1.4, 1.5, 1.7, 1.9, 2.1, 2.3, 2.5, 2.7, 2.9]

# %%
directory = 'AIJ'
rotation = 'X001'
path = 'C:/Users/ylinh/OneDrive - UW/Exoplanetary Atmospheres/'+directory+'/'
var = 'tsurf'

files = [os.path.basename(file) for file in glob.glob(path +'/*'+rotation+'*.nc')]
files = sorted(files, key=sorter)
# name = files[0]
# data = Dataset(path + name,'r') # loading this to automatically population plot titles\

fig = plt.figure(figsize=(28, 16))
gs = gridspec.GridSpec(4, 4)
gs.update(hspace=.1, wspace=.07)
ax = []

min_val = 0 # for contour levels and colorbar
max_val = 100

for i in range(len(files)):
    var1, latGrid, lonGrid = mr.open_ROCKE3D(path, files[i], var)
#     print('S0X = '+str(insolation[i])+' for '+ str(files[i]))

    ax.append(plt.subplot(gs[i], projection=ccrs.PlateCarree()))
    ax[i].contourf(lonGrid, latGrid, var1, levels=np.linspace(min_val, max_val,1000), cmap='Spectral_r')
    ax[i].set_xlim(-180,180)
    ax[i].set_ylim(-90,90)
    ax[i].coastlines()
    ax[i].set_title('S0X = '+str(insolation[i])+', Rotation Rate = ' + rotation +', DO')
    
# plot colorbar
ax.append(plt.subplot(gs[3, 1:3]))
norm = mpl.colors.Normalize(vmin=min_val, vmax=max_val)
cbar = colorbar.ColorbarBase(ax[i+1],cmap=plt.get_cmap('Spectral_r'),
                             norm=norm,orientation='horizontal')
cbar.ax.set_aspect(.08)
cbar.set_label(data[var].long_name +' ('+ data[var].units+')')

plt.show()

# %%
directory = 'AIJ'
rotation = 'X016'
path = 'C:/Users/ylinh/OneDrive - UW/Exoplanetary Atmospheres/'+directory+'/'
var = 'tsurf'

files = [os.path.basename(file) for file in glob.glob(path +'/*'+rotation+'*.nc')]
files = sorted(files, key=sorter)
# name = files[0]
# data = Dataset(path + name,'r') # loading this to automatically population plot titles\

fig = plt.figure(figsize=(28, 16))
gs = gridspec.GridSpec(4, 4)
gs.update(hspace=.1, wspace=.07)
ax = []

min_val = 0 # for contour levels and colorbar
max_val = 100

for i in range(len(files)):
    var1, latGrid, lonGrid = mr.open_ROCKE3D(path, files[i], var)
#     print('S0X = '+str(insolation[i])+' for '+ str(files[i]))

    ax.append(plt.subplot(gs[i], projection=ccrs.PlateCarree()))
    ax[i].contourf(lonGrid, latGrid, var1, levels=np.linspace(min_val, max_val,1000), cmap='Spectral_r')
    ax[i].set_xlim(-180,180)
    ax[i].set_ylim(-90,90)
    ax[i].coastlines()
    ax[i].set_title('S0X = '+str(insolation[i])+', Rotation Rate = ' + rotation +', DO')
    
# plot colorbar
ax.append(plt.subplot(gs[3, 1:3]))
norm = mpl.colors.Normalize(vmin=min_val, vmax=max_val)
cbar = colorbar.ColorbarBase(ax[i+1],cmap=plt.get_cmap('Spectral_r'),
                             norm=norm,orientation='horizontal')
cbar.ax.set_aspect(.08)
cbar.set_label(data[var].long_name +' ('+ data[var].units+')')

plt.show()

# %%
directory = 'AIJ'
rotation = 'X064'
path = 'C:/Users/ylinh/OneDrive - UW/Exoplanetary Atmospheres/'+directory+'/'
var = 'tsurf'

files = [os.path.basename(file) for file in glob.glob(path +'/*'+rotation+'*.nc')]
files = sorted(files, key=sorter)
# name = files[0]
# data = Dataset(path + name,'r') # loading this to automatically population plot titles\

fig = plt.figure(figsize=(28, 16))
gs = gridspec.GridSpec(4, 4)
gs.update(hspace=.1, wspace=.07)
ax = []

min_val = 0 # for contour levels and colorbar
max_val = 100

for i in range(len(files)):
    var1, latGrid, lonGrid = mr.open_ROCKE3D(path, files[i], var)
#     print('S0X = '+str(insolation[i])+' for '+ str(files[i]))

    ax.append(plt.subplot(gs[i], projection=ccrs.PlateCarree()))
    ax[i].contourf(lonGrid, latGrid, var1, levels=np.linspace(min_val, max_val,1000), cmap='Spectral_r')
    ax[i].set_xlim(-180,180)
    ax[i].set_ylim(-90,90)
    ax[i].coastlines()
    ax[i].set_title('S0X = '+str(insolation[i])+', Rotation Rate = ' + rotation +', DO')
    
# plot colorbar
ax.append(plt.subplot(gs[3, 1:3]))
norm = mpl.colors.Normalize(vmin=min_val, vmax=max_val)
cbar = colorbar.ColorbarBase(ax[i+1],cmap=plt.get_cmap('Spectral_r'),
                             norm=norm,orientation='horizontal')
cbar.ax.set_aspect(.08)
cbar.set_label(data[var].long_name +' ('+ data[var].units+')')

plt.show()

# %%
directory = 'AIJ'
rotation = 'X256'
path = 'C:/Users/ylinh/OneDrive - UW/Exoplanetary Atmospheres/'+directory+'/'
var = 'tsurf'

files = [os.path.basename(file) for file in glob.glob(path +'/*'+rotation+'*.nc')]
files = sorted(files, key=sorter)
# name = files[0]
# data = Dataset(path + name,'r') # loading this to automatically population plot titles\

fig = plt.figure(figsize=(28, 16))
gs = gridspec.GridSpec(4, 4)
gs.update(hspace=.1, wspace=.07)
ax = []

min_val = 0 # for contour levels and colorbar
max_val = 100

for i in range(len(files)):
    var1, latGrid, lonGrid = mr.open_ROCKE3D(path, files[i], var)
#     print('S0X = '+str(insolation[i])+' for '+ str(files[i]))

    ax.append(plt.subplot(gs[i], projection=ccrs.PlateCarree()))
    ax[i].contourf(lonGrid, latGrid, var1, levels=np.linspace(min_val, max_val,1000), cmap='Spectral_r')
    ax[i].set_xlim(-180,180)
    ax[i].set_ylim(-90,90)
    ax[i].coastlines()
    ax[i].set_title('S0X = '+str(insolation[i])+', Rotation Rate = ' + rotation +', DO')
    
# plot colorbar
ax.append(plt.subplot(gs[3, 1:3]))
norm = mpl.colors.Normalize(vmin=min_val, vmax=max_val)
cbar = colorbar.ColorbarBase(ax[i+1],cmap=plt.get_cmap('Spectral_r'),
                             norm=norm,orientation='horizontal')
cbar.ax.set_aspect(.08)
cbar.set_label(data[var].long_name +' ('+ data[var].units+')')

plt.show()
